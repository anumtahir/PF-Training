# %% [markdown]
# ### Following code is to load an image using cv2 library. cv2 library loads the image as numpy array. Fill missing code to replace red pixels with black codes.

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt 


im_path = "baboon.png"
im_array = cv2.imread(im_path)
display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))


#your code to replace

minimum = (0,0,100)
maximum = (255,100,255)
convert = cv2.inRange(im_array, minimum, maximum)
im_array[convert != 0] = (0, 0, 0)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F1A43349ED0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F1A433497B0>
